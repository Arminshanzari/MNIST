# %%
#hand written digits, DS: search, algorythmes =>  naive bayes , knn, logistic regression , Neural Networks

# %%
import numpy as np
from sklearn import datasets as ds
from sklearn import svm, metrics
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# %%
hd = ds.load_digits()

# %%
help(ax.set_title)

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize = (10, 6))
axes = axes.flatten()
for ax, image, target in zip(axes, hd.images, hd.target):
    ax.set_axis_off()
    ax.imshow(image, cmap = 'gray_r')
    ax.set_title('number %i:' % target)

# %% [markdown]
# Flatten the images:

# %%
n_samples = len(hd.images)
print(n_samples)
# Out:
# 1797

# %%
data = hd.images.reshape((n_samples, -1))

# %% [markdown]
# train test split:

# %%
X,  X_test, y, y_test = train_test_split(data, hd.target, test_size = 0.4)
print(np.shape(X),np.shape(y),np.shape(X_test),np.shape(y_test))
# Out:
# (1078, 64) (1078,) (719, 64) (719,)

# %% [markdown]
# creating the clasifier(svm) and train:

# %%
clsvm = svm.SVC(gamma = 0.001)
clsvm.fit(X, y)
# Out:
# SVC(gamma=0.001)
